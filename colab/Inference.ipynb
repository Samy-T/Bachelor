# %%
# !nvidia-smi
# Out:
# Tue Jun 15 13:09:22 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.27       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   38C    P0    25W / 300W |      0MiB / 16160MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install efficientnet_pytorch
# Out:
# ...
#   Created wheel for efficientnet-pytorch: filename=efficientnet_pytorch-0.7.1-cp37-none-any.whl size=16443 sha256=d4cf95f32242ca3a82baa3001740a15068eee0c8be32a07a94fdcb220c7b6e02
#   Stored in directory: /root/.cache/pip/wheels/84/27/aa/c46d23c4e8cc72d41283862b1437e0b3ad318417e8ed7d5921
# Successfully built efficientnet-pytorch
# ...

# %%
# !apt-get install -y xvfb python-opengl > /dev/null 2>&1

# %%
cd ..
# Out:
# /content/drive/My Drive/Turculescu

# %% [markdown]
# # Demo

# %%
cd content/drive/MyDrive/Demo/
# Out:
# /content/drive/MyDrive/Demo

# %%
# !xvfb-run python inference.py --input inputs/Video_Test.mp4 --number_of_frames 8
# Out:
# Number of frames to consider for each prediction: 8
# Doing other things
# Doing other things
# Doing other things
# Thumb Up
# Thumb Up
# Thumb Up
# Thumb Up
# Thumb Up
# Thumb Up
# Thumb Up
# Thumb Up
# Thumb Up
# Thumb Up
# Thumb Up
# Thumb Up
# Thumb Up
# Thumb Up
# Thumb Up
# Thumb Up
# Thumb Up
# Thumb Up
# Thumb Up
# Thumb Up
# Thumb Up
# Thumb Up
# Thumb Up
# Thumb Up
# Thumb Up
# Thumb Up
# Thumb Up
# Thumb Up
# Thumb Up
# Thumb Up
# Thumb Up
# Thumb Up
# Thumb Up
# Thumb Up
# Thumb Up
# Thumb Up
# Thumb Up
# Thumb Up
# Thumb Up
# Thumb Up
# Thumb Up
# Thumb Up
# Thumb Up
# Thumb Up
# Thumb Up
# Sliding Two Fingers Down
# Sliding Two Fingers Down
# Sliding Two Fingers Down
# Doing other things
# No gesture
# No gesture
# No gesture
# No gesture
# No gesture
# No gesture
# No gesture
# No gesture
# No gesture
# No gesture
# No gesture
# No gesture
# No gesture
# No gesture
# Doing other things
# No gesture
# No gesture
# No gesture
# No gesture
# No gesture
# No gesture
# ...

# %% [markdown]
# # Inference

# %%
cd /content/drive/MyDrive/Turculescu/Inference
# Out:
# /content/drive/MyDrive/Turculescu/Inference

# %%
# !xvfb-run python inference.py --input inputs/Smt-Smt_Test.webm --number_of_frames 8
# Out:
# Number of frames to consider for each prediction: 8
# Showing something to the camera
# Showing something to the camera
# Holding something over something
# Holding something behind something
# Holding something behind something
# Holding something over something
# Holding something over something
# Holding something over something
# Holding something over something
# Holding something over something
# Holding something over something
# Holding something over something
# Holding something over something
# Holding something
# Showing something to the camera
# Showing something to the camera
# Attaching something to something
# Putting something into something
# Showing something to the camera
# Holding something
# Holding something
# Holding something
# Pretending to pour something out of something, but something is empty
# Something falling like a feather or paper
# Something falling like a feather or paper
# Dropping something onto something
# Dropping something behind something
# ...

# %%
# !xvfb-run python inference.py --input inputs/UCF101_Test.mp4 --number_of_frames 8
# Out:
# Number of frames to consider for each prediction: 8
# Loaded pretrained weights for efficientnet-b4
# Knitting
# Knitting
# PlayingGuitar
# Knitting
# PlayingGuitar
# PlayingGuitar
# PlayingGuitar
# PlayingGuitar
# PlayingGuitar
# Knitting
# Knitting
# Knitting
# Knitting
# Knitting
# Knitting
# Knitting
# PlayingGuitar
# PlayingGuitar
# PlayingGuitar
# Knitting
# Knitting
# Knitting
# Knitting
# Knitting
# PlayingGuitar
# PlayingGuitar
# PlayingGuitar
# PlayingGuitar
# PlayingGuitar
# PlayingGuitar
# PlayingGuitar
# PlayingGuitar
# PlayingGuitar
# PlayingGuitar
# PlayingGuitar
# PlayingGuitar
# PlayingSitar
# PlayingSitar
# Typing
# Typing
# Typing
# Knitting
# Knitting
# Knitting
# Knitting
# Typing
# Typing
# Typing
# Knitting
# Knitting
# Typing
# Typing
# Typing
# Typing
# Typing
# Typing
# Typing
# Typing
# Typing
# Typing
# Typing
# Typing
# Typing
# Typing
# Typing
# Typing
# Typing
# Typing
# Knitting
# Knitting
# Knitting
# Knitting
# Knitting
# Knitting
# Knitting
# ...

# %%
# !xvfb-run python inference.py --input inputs/HMDB51_Test_1.avi --number_of_frames 8
# Out:
# Number of frames to consider for each prediction: 8
# Loaded pretrained weights for efficientnet-b4
# brush_hair
# brush_hair
# brush_hair
# brush_hair
# brush_hair
# brush_hair
# brush_hair
# brush_hair
# brush_hair
# brush_hair
# brush_hair
# brush_hair
# brush_hair
# brush_hair
# brush_hair
# brush_hair
# brush_hair
# brush_hair
# brush_hair
# brush_hair
# brush_hair
# brush_hair
# brush_hair
# brush_hair
# brush_hair
# brush_hair
# brush_hair
# brush_hair
# brush_hair
# brush_hair
# brush_hair
# brush_hair
# brush_hair
# brush_hair
# brush_hair
# brush_hair
# brush_hair
# brush_hair
# brush_hair
# brush_hair
# brush_hair
# brush_hair
# brush_hair
# brush_hair
# brush_hair
# brush_hair
# brush_hair
# brush_hair
# brush_hair
# brush_hair
# brush_hair
# brush_hair
# brush_hair
# brush_hair
# brush_hair
# brush_hair
# brush_hair
# brush_hair
# brush_hair
# brush_hair
# brush_hair
# brush_hair
# brush_hair
# brush_hair
# brush_hair
# brush_hair
# brush_hair
# brush_hair
# brush_hair
# ...

# %%
# !xvfb-run python inference.py --input inputs/Jester_Test_1.mp4 --number_of_frames 8
# Out:
# Number of frames to consider for each prediction: 8
# Doing other things
# Doing other things
# Thumb Up
# Thumb Up
# Thumb Up
# Thumb Up
# Thumb Up
# Thumb Up
# Thumb Up
# Thumb Up
# Thumb Up
# Thumb Up
# Thumb Up
# Thumb Up
# Thumb Up
# Thumb Up
# Thumb Up
# Thumb Up
# Thumb Up
# Thumb Up
# Thumb Up
# Thumb Up
# Thumb Up
# Thumb Up
# Thumb Up
# Thumb Up
# Thumb Up
# Thumb Up
# Thumb Up
# Thumb Up
# Thumb Up
# Thumb Up
# Thumb Up
# Thumb Up
# Thumb Up
# Thumb Up
# Thumb Up
# Thumb Up
# Thumb Up
# Thumb Up
# Thumb Up
# Thumb Up
# Thumb Up
# Thumb Up
# Thumb Up
# Thumb Up
# Thumb Up
# Sliding Two Fingers Right
# Sliding Two Fingers Down
# Sliding Two Fingers Down
# Sliding Two Fingers Down
# Doing other things
# No gesture
# No gesture
# Doing other things
# Doing other things
# No gesture
# No gesture
# No gesture
# No gesture
# No gesture
# No gesture
# No gesture
# No gesture
# No gesture
# No gesture
# Doing other things
# No gesture
# No gesture
# No gesture
# No gesture
# ...

# %%
# !xvfb-run python inference.py --input inputs/Jester_Test_2.MP4 --number_of_frames 8
# Out:
# Number of frames to consider for each prediction: 8
# No gesture
# No gesture
# No gesture
# No gesture
# Doing other things
# Doing other things
# Doing other things
# Doing other things
# Doing other things
# No gesture
# No gesture
# No gesture
# No gesture
# No gesture
# No gesture
# No gesture
# Doing other things
# Doing other things
# Doing other things
# Doing other things
# Doing other things
# Sliding Two Fingers Up
# Drumming Fingers
# Drumming Fingers
# Drumming Fingers
# Drumming Fingers
# Drumming Fingers
# Drumming Fingers
# Drumming Fingers
# Drumming Fingers
# Drumming Fingers
# Drumming Fingers
# Drumming Fingers
# Drumming Fingers
# Drumming Fingers
# Drumming Fingers
# Drumming Fingers
# Drumming Fingers
# Drumming Fingers
# Drumming Fingers
# Drumming Fingers
# Drumming Fingers
# Drumming Fingers
# Drumming Fingers
# Drumming Fingers
# Drumming Fingers
# Drumming Fingers
# Drumming Fingers
# Drumming Fingers
# Drumming Fingers
# Drumming Fingers
# ...

# %%
# !xvfb-run python inference.py --input inputs/Jester_Test_3.MP4 --number_of_frames 8
# Out:
# Number of frames to consider for each prediction: 8
# Zooming Out With Two Fingers
# Zooming Out With Two Fingers
# Zooming Out With Two Fingers
# Zooming Out With Two Fingers
# Zooming In With Two Fingers
# Zooming Out With Two Fingers
# Doing other things
# Zooming In With Two Fingers
# Shaking Hand
# Shaking Hand
# Zooming In With Two Fingers
# Zooming In With Two Fingers
# Zooming In With Two Fingers
# Zooming In With Two Fingers
# Zooming In With Two Fingers
# Zooming In With Two Fingers
# Zooming In With Two Fingers
# Shaking Hand
# Zooming Out With Two Fingers
# Zooming In With Two Fingers
# Zooming In With Two Fingers
# Zooming Out With Two Fingers
# Doing other things
# Shaking Hand
# Doing other things
# Shaking Hand
# Shaking Hand
# Shaking Hand
# Zooming Out With Full Hand
# Zooming Out With Full Hand
# Zooming Out With Full Hand
# Zooming Out With Full Hand
# Zooming In With Full Hand
# Zooming In With Two Fingers
# Zooming In With Two Fingers
# ...
